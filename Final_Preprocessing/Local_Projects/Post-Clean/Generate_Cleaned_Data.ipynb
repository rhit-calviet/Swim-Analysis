# %%
import pandas as pd

# %%
df = pd.read_parquet('CLEANED_SWIM_DATA.parquet')
df.head()
# Out:
#                    Event  Conf_Rank   Time             Name  \
# 0  50 Freestyle SCY Male         -1  21.22      Ben Beldner
# 1  50 Freestyle SCY Male         -1  20.87      Justin Meyn
# 2  50 Freestyle SCY Male         -1  21.31    Joshua Franco
# 3  50 Freestyle SCY Male         -1  21.05  Gabe Laracuente
# 4  50 Freestyle SCY Male         -1  21.70       Ryan Board
#
#                                School Standard       Date Gender Division  \
# 0                          Binghamton       NA 2000-01-01      M       HS
# 1                          Binghamton       NA 2000-01-01      M       HS
# 2  New Jersey Institute of Technology       NA 2000-01-01      M       HS
# 3                                UMBC       NA 2000-01-01      M       HS
# 4                          Binghamton       NA 2000-01-01      M       HS
#
#   Season  SeasonYear               Time_Adj  Time_Sec  Div_Rank  NCAA_Rank  \
# 0  00_01        2001 0 days 00:00:21.220000     21.22        -1         -1
# ...

# %%
df.shape
# Out:
# (358106, 20)

# %%
df[df.Name=='Vineet Ranade']
# Out:
#                                  Event  Conf_Rank      Time           Name  \
# 2787             50 Freestyle SCY Male         -1     21.81  Vineet Ranade
# 13941           100 Freestyle SCY Male         -1     46.86  Vineet Ranade
# 24872           200 Freestyle SCY Male         -1   1:41.96  Vineet Ranade
# 34949           500 Freestyle SCY Male         -1   4:37.66  Vineet Ranade
# 42965          1000 Freestyle SCY Male         -1   9:59.66  Vineet Ranade
# 48146          1650 Freestyle SCY Male         -1  16:50.68  Vineet Ranade
# 54083          100 Backstroke SCY Male         -1     53.46  Vineet Ranade
# 63578          200 Backstroke SCY Male         -1   1:58.60  Vineet Ranade
# 72349        100 Breaststroke SCY Male         -1     58.91  Vineet Ranade
# 80881        200 Breaststroke SCY Male         -1   2:06.62  Vineet Ranade
# 88884           100 Butterfly SCY Male         -1     50.59  Vineet Ranade
# ...

# %%
df.head(1)
# Out:
#                    Event  Conf_Rank   Time         Name      School Standard  \
# 0  50 Freestyle SCY Male         -1  21.22  Ben Beldner  Binghamton       NA
#
#         Date Gender Division Season  SeasonYear               Time_Adj  \
# 0 2000-01-01      M       HS  00_01        2001 0 days 00:00:21.220000
#
#    Time_Sec  Div_Rank  NCAA_Rank      ID  Power_Tot  Power  Record     Points
# 0     21.22        -1         -1  394588      22.71  20.52   17.63  573.48333

# %%
sw = df[['Name','School','Gender','Division','SeasonYear','ID','Power_Tot']]
sw = sw.drop_duplicates()
sw.head()
# Out:
#               Name                              School Gender Division  \
# 0      Ben Beldner                          Binghamton      M       HS
# 1      Justin Meyn                          Binghamton      M       HS
# 2    Joshua Franco  New Jersey Institute of Technology      M       HS
# 3  Gabe Laracuente                                UMBC      M       HS
# 4       Ryan Board                          Binghamton      M       HS
#
#    SeasonYear      ID  Power_Tot
# 0        2001  394588      22.71
# 1        2001  471360      10.06
# 2        2001  395308      12.40
# 3        2001  404642      13.77
# 4        2001  422211      18.21

# %%
sw.shape
# Out:
# (50151, 7)

# %%
sw.Name.nunique()
# Out:
# 11242

# %%
sw[sw.Name=='Nicholas Edwards']
# Out:
#                     Name                                School Gender  \
# 7241    Nicholas Edwards   Rose-Hulman Institute of Technology      M
# 13219   Nicholas Edwards  Western Connecticut State University      M
# 186216  Nicholas Edwards  Western Connecticut State University      M
# 196031  Nicholas Edwards   Rose-Hulman Institute of Technology      M
# 197373  Nicholas Edwards  Western Connecticut State University      M
# 217922  Nicholas Edwards   Rose-Hulman Institute of Technology      M
#
#        Division  SeasonYear      ID  Power_Tot
# 7241         HS        2001  663038      25.38
# 13219        HS        2001  490867     100.00
# 186216      III        2020  490867     100.00
# 196031      III        2022  663038      25.38
# 197373      III        2022  490867     100.00
# 217922      III        2023  663038      25.38

# %%
school_counts = df.groupby('Name')['School'].nunique()

# Filter for names with more than one school
names_with_multiple_schools = school_counts[school_counts > 1]

# Count how many names have more than one school
len(names_with_multiple_schools)
# Out:
# 1198

# %%
df.head()
# Out:
#                    Event  Conf_Rank   Time             Name  \
# 0  50 Freestyle SCY Male         -1  21.22      Ben Beldner
# 1  50 Freestyle SCY Male         -1  20.87      Justin Meyn
# 2  50 Freestyle SCY Male         -1  21.31    Joshua Franco
# 3  50 Freestyle SCY Male         -1  21.05  Gabe Laracuente
# 4  50 Freestyle SCY Male         -1  21.70       Ryan Board
#
#                                School Standard       Date Gender Division  \
# 0                          Binghamton       NA 2000-01-01      M       HS
# 1                          Binghamton       NA 2000-01-01      M       HS
# 2  New Jersey Institute of Technology       NA 2000-01-01      M       HS
# 3                                UMBC       NA 2000-01-01      M       HS
# 4                          Binghamton       NA 2000-01-01      M       HS
#
#   Season  SeasonYear               Time_Adj  Time_Sec  Div_Rank  NCAA_Rank  \
# 0  00_01        2001 0 days 00:00:21.220000     21.22        -1         -1
# ...

# %%
sw = df[['Name','School','Gender','Division','SeasonYear','ID','Power_Tot']]
sw = sw.drop_duplicates()
sw.head()
# Out:
#               Name                              School Gender Division  \
# 0      Ben Beldner                          Binghamton      M       HS
# 1      Justin Meyn                          Binghamton      M       HS
# 2    Joshua Franco  New Jersey Institute of Technology      M       HS
# 3  Gabe Laracuente                                UMBC      M       HS
# 4       Ryan Board                          Binghamton      M       HS
#
#    SeasonYear      ID  Power_Tot
# 0        2001  394588      22.71
# 1        2001  471360      10.06
# 2        2001  395308      12.40
# 3        2001  404642      13.77
# 4        2001  422211      18.21

# %%
df[df.Name=='Nicholas Edwards']
# Out:
#                                  Event  Conf_Rank     Time              Name  \
# 7241             50 Freestyle SCY Male         -1    22.16  Nicholas Edwards
# 13219           100 Freestyle SCY Male         -1    55.88  Nicholas Edwards
# 19166           100 Freestyle SCY Male         -1    47.46  Nicholas Edwards
# 24176           200 Freestyle SCY Male         -1  2:02.20  Nicholas Edwards
# 30074           200 Freestyle SCY Male         -1  1:42.13  Nicholas Edwards
# 39549           500 Freestyle SCY Male         -1  4:49.74  Nicholas Edwards
# 59347          100 Backstroke SCY Male         -1    55.34  Nicholas Edwards
# 68001          200 Backstroke SCY Male         -1  1:59.80  Nicholas Edwards
# 68647          200 Backstroke LCM Male         -1  2:59.87  Nicholas Edwards
# 77343        100 Breaststroke SCY Male         -1    59.70  Nicholas Edwards
# 84656        200 Breaststroke SCY Male         -1  2:14.51  Nicholas Edwards
# ...

# %%
df.to_parquet('CLEANED_SWIM_DATA.parquet',index=False)

# %%
sw.Name = sw.Name.astype('category')
sw.dtypes
# Out:
# Name          category
# School        category
# Gender        category
# Division      category
# SeasonYear       int64
# ID               int64
# Power_Tot      float64
# dtype: object

# %%
sw.to_parquet('CLEANED_SWIMMER_INFO.parquet',index=False)
