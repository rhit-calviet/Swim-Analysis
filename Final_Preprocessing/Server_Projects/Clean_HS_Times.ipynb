# %%
import pandas as pd

# %%
df = pd.read_csv('HS_times.csv')
df.head(2)
# Out:
# /tmp/ipykernel_1164484/4253219970.py:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('HS_times.csv')
#        ID 50 Y Free Time 50 S Free Time 50 L Free Time 100 Y Free Time  \
# 0  515075            NaN            NaN          23.31             NaN
# 1  413265            NaN            NaN          23.60           44.36
#
#   100 S Free Time 100 L Free Time 200 Y Free Time 200 S Free Time  \
# 0           50.21             NaN             NaN         1:50.45
# 1             NaN             NaN         1:37.44             NaN
#
#   200 L Free Time  ... 200 S Fly Points 200 L Fly Points 100 Y IM Points  \
# 0             NaN  ...              NaN              NaN             NaN
# 1             NaN  ...              NaN              NaN           100.0
#
#   100 S IM Points 200 Y IM Points 200 S IM Points 200 L IM Points  \
# 0             NaN             NaN             NaN             NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12402 entries, 0 to 12401
# Data columns (total 89 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   12402 non-null  int64
#  1   50 Y Free Time       7936 non-null   object
#  2   50 S Free Time       308 non-null    object
#  3   50 L Free Time       3671 non-null   object
#  4   100 Y Free Time      8985 non-null   object
#  5   100 S Free Time      361 non-null    object
#  6   100 L Free Time      2524 non-null   object
#  7   200 Y Free Time      8987 non-null   object
#  8   200 S Free Time      333 non-null    object
#  9   200 L Free Time      2026 non-null   object
#  10  500 Y Free Time      7936 non-null   object
#  11  400 S Free Time      292 non-null    object
#  12  400 L Free Time      1838 non-null   object
#  13  1000 Y Free Time     4114 non-null   object
#  14  800 S Free Time      161 non-null    object
# ...

# %%
df.index = df.index.astype('category')

# %%
for col in df.columns[1:45]:
    df[col] = df[col].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 12402 entries, 0 to 12401
# Data columns (total 89 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   12402 non-null  int64
#  1   50 Y Free Time       7936 non-null   string
#  2   50 S Free Time       308 non-null    string
#  3   50 L Free Time       3671 non-null   string
#  4   100 Y Free Time      8985 non-null   string
#  5   100 S Free Time      361 non-null    string
#  6   100 L Free Time      2524 non-null   string
#  7   200 Y Free Time      8987 non-null   string
#  8   200 S Free Time      333 non-null    string
#  9   200 L Free Time      2026 non-null   string
#  10  500 Y Free Time      7936 non-null   string
#  11  400 S Free Time      292 non-null    string
#  12  400 L Free Time      1838 non-null   string
#  13  1000 Y Free Time     4114 non-null   string
#  14  800 S Free Time      161 non-null    string
# ...

# %%
df.to_parquet('HS_times_cleaned.parquet',index=True)

# %%
names = pd.read_parquet('4more_name_info_dtypes.parquet')
names.head(2)
# Out:
#              Name School  Power             Link
# 0   Tiago ASAKAWA   UMBC  15.96  /swimmer/515075
# 1  Niklas Weigelt   UMBC   8.38  /swimmer/413265

# %%
names['ID'] = names['Link'].apply(lambda x: x.split('/')[-1])
names.head(2)
# Out:
#              Name School  Power             Link      ID
# 0   Tiago ASAKAWA   UMBC  15.96  /swimmer/515075  515075
# 1  Niklas Weigelt   UMBC   8.38  /swimmer/413265  413265

# %%
names = names.set_index('ID')
names = names.drop('Link',axis=1)
names.head(2)
# Out:
#                   Name School  Power
# ID
# 515075   Tiago ASAKAWA   UMBC  15.96
# 413265  Niklas Weigelt   UMBC   8.38

# %%
names.to_parquet('cleaned_names.parquet',index=True)
