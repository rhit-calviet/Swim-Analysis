# %%
import pandas as pd

# %%
hs = pd.read_parquet('corrected_cleaned_HS.parquet')
hs.head(2)
# Out:
#         index            Name School  Power 50 Y Free Time 50 S Free Time  \
# ID
# 515075      0   Tiago ASAKAWA   UMBC  15.96           <NA>           <NA>
# 413265      1  Niklas Weigelt   UMBC   8.38           <NA>           <NA>
#
#        50 L Free Time 100 Y Free Time 100 S Free Time 100 L Free Time  ...  \
# ID                                                                     ...
# 515075          23.31            <NA>           50.21            <NA>  ...
# 413265          23.60           44.36            <NA>            <NA>  ...
#
#        200 S Fly Points 200 L Fly Points 100 Y IM Points 100 S IM Points  \
# ID
# 515075              NaN              NaN             NaN             NaN
# 413265              NaN              NaN           100.0             NaN
#
#        200 Y IM Points 200 S IM Points 200 L IM Points 400 Y IM Points  \
# ID
# 515075             NaN             NaN             NaN             NaN
# 413265           18.97             NaN             NaN           100.0
#
#        400 S IM Points 400 L IM Points
# ID
# 515075             NaN             NaN
# 413265             NaN             NaN
#
# [2 rows x 92 columns]

# %%
col = pd.read_parquet('4YR_cleaned_USAS.parquet')
col.head(2)
# Out:
#                    Event  Conf_Rank   Time            Name School Standard  \
# 0  50 Freestyle SCY Male          2  20.20   Tiago ASAKAWA   UMBC       NS
# 1  50 Freestyle SCY Male          4  20.72  Niklas Weigelt   UMBC       NS
#
#         Date Gender Division Season  SeasonYear               Time_Adj  \
# 0 2020-02-14      M        I  19_20        2020 0 days 00:00:20.200000
# 1 2020-02-14      M        I  19_20        2020 0 days 00:00:20.720000
#
#    Time_Sec      Points  Div_Rank  NCAA_Rank  Power
# 0     20.20  664.818090     252.0      291.0  15.96
# 1     20.72  616.009888     542.0      690.0   8.38

# %%
hs.shape
# Out:
# (11587, 92)

# %%
col.shape
# Out:
# (299511, 17)

# %%
hs.Name.nunique()
# Out:
# 11243

# %%
col.Name.nunique()
# Out:
# 14556

# %%
hs[hs.Name=='Aidan Wilson']
# Out:
#          index          Name                        School  Power  \
# ID
# 608415    1358  Aidan Wilson              Brown University   7.12
# 1317892  12980  Aidan Wilson  Kings College (Pennsylvania)  83.03
#
#         50 Y Free Time 50 S Free Time 50 L Free Time 100 Y Free Time  \
# ID
# 608415           22.91           <NA>           <NA>           48.04
# 1317892          24.06           <NA>           <NA>           53.61
#
#         100 S Free Time 100 L Free Time  ... 200 S Fly Points  \
# ID                                       ...
# 608415             <NA>            <NA>  ...              NaN
# 1317892            <NA>            <NA>  ...              NaN
#
#         200 L Fly Points 100 Y IM Points 100 S IM Points 200 Y IM Points  \
# ID
# 608415               NaN           62.68             NaN           21.95
# 1317892              NaN             NaN             NaN          100.00
#
#         200 S IM Points 200 L IM Points 400 Y IM Points 400 S IM Points  \
# ID
# 608415              NaN             NaN            9.52             NaN
# 1317892             NaN             NaN             NaN             NaN
#
#         400 L IM Points
# ID
# 608415              NaN
# 1317892             NaN
#
# [2 rows x 92 columns]

# %%
hs.at[1052055,'Name']='Aidan Wilson'

# %%
unique_names_hs = hs['Name'].unique().tolist()
unique_names_col = col['Name'].unique().tolist()

# %%
unique_names_hs_lower = [name.lower() for name in unique_names_hs]
unique_names_col_lower = [name.lower() for name in unique_names_col]

count = 0
for name in unique_names_hs_lower:
    found = False
    for name2 in unique_names_col_lower:
        if (name == name2):
            found = True
    if (found == False):
        count = count + 1
        print(name)
print(count)
# Out:
# 0

# %%
hs = hs.reset_index().drop('index',axis=1)
hs.head(2)
# Out:
#        ID            Name School  Power 50 Y Free Time 50 S Free Time  \
# 0  515075   Tiago ASAKAWA   UMBC  15.96           <NA>           <NA>
# 1  413265  Niklas Weigelt   UMBC   8.38           <NA>           <NA>
#
#   50 L Free Time 100 Y Free Time 100 S Free Time 100 L Free Time  ...  \
# 0          23.31            <NA>           50.21            <NA>  ...
# 1          23.60           44.36            <NA>            <NA>  ...
#
#   200 S Fly Points 200 L Fly Points 100 Y IM Points 100 S IM Points  \
# 0              NaN              NaN             NaN             NaN
# 1              NaN              NaN           100.0             NaN
#
#   200 Y IM Points 200 S IM Points 200 L IM Points 400 Y IM Points  \
# 0             NaN             NaN             NaN             NaN
# 1           18.97             NaN             NaN           100.0
#
#   400 S IM Points 400 L IM Points
# 0             NaN             NaN
# 1             NaN             NaN
#
# [2 rows x 92 columns]

# %%
col_filtered = col[col['Name'].str.lower().isin(unique_names_hs_lower)]

# %%
col_filtered.shape
# Out:
# (231748, 17)

# %%
name_mapping = {
    'Fla Atlantic (M)': 'Florida Atlantic University',
    'Fla Atlantic (W)': 'Florida Atlantic University',
    'Loyola (MD)': 'Loyola University (Maryland)',
    'U.S. Navy': 'U.S. Naval Academy (Navy)',
    'UW-Stevens Point': 'University of Wisconsin-Stevens Point',
    'UWEC': 'University of Wisconsin-Eau Claire',
    'Wash U. MO': 'Washington University (Missouri)',
    'Georgia Tech': 'Georgia Institute of Technology',
    'Virginia MI': 'Virginia Military Institute',
    'Iona Coll': 'Iona University',
    'Wheaton IL': 'Wheaton College (Illinois)',
    'TCNJ': 'College of New Jersey, The',
    'UMSL': 'University of Missouri-St. Louis',
    'Henderson St.': 'Henderson State University',
    'IWU': 'Indiana Wesleyan University',
    'SMU': 'Southern Methodist University',
    'UCSB': 'University of California-Santa Barbara',
    'Missouri St (W)': 'Missouri State University',
    'NC State': 'North Carolina State University',
    'USMMA': 'U.S. Merchant Marine Academy',
    'NDC': 'Notre Dame (Ohio) College',
    'Air Force (W)': 'U.S. Air Force Academy',
    'St. Norbert': 'St Norbert College',
    'W&L': 'Washington and Lee University',
    'UNC Wilmington': 'University of North Carolina, Wilmington',
    'SHIP': 'Shippensburg University',
    'IU Indianapolis': 'Indiana University-Indianapolis',
    'Cal Poly': 'California Polytechnic State University',
    'BSC': 'Birmingham Southern College',
    'Wyoming (M)': 'University of Wyoming',
    'MIT': 'Massachusetts Institute of Technology',
    'Bryant U (W)': 'Bryant University',
    'St. Louis': 'Saint Louis University',
    'UN Omaha': 'University of Nebraska, Omaha',
    'TAMPA': 'University of Tampa',
    'Claremont MS': 'Claremont McKenna-Harvey Mudd-Scripps Colleges',
    'Wheaton MA': 'Wheaton College (Massachusetts)',
    'Evansville (M)': 'University of Evansville',
    'Fla Atlantic (M)': 'Florida Atlantic University',
    'UNE': 'University of New England',
    'Trinity C.': 'Trinity College (Connecticut)',
    'SUNY Geneseo': 'State University of New York at Geneseo',
    'Catholic UA': 'Catholic University',
    'Colorado St.': 'Colorado State University',
    'Frostburg St.': 'Frostburg State University',
    'UNC': 'University of North Carolina, Chapel Hill',
    'F&M': 'Franklin & Marshall College',
    'SUNY Brockport': 'State University of New York at Brockport',
    'Indy': 'University of Indianapolis',
    'Wyoming (W)': 'University of Wyoming',
    'NYU': 'New York University',
    'RIT': 'Rochester Institute of Technology',
    "St. John's": 'Saint Johns University',
    'St. Cloud St.-M': 'Saint Cloud State University',
    'TCU': 'Texas Christian University',
    'Truman St.': 'Truman State University',
    'Caltech': 'California Institute of Technology',
    'Evansville (W)': 'University of Evansville',
    'FDU-Florham': 'Fairleigh Dickinson University, Madison',
    'Illinois-Chicago': 'University of Illinois at Chicago',
    'Xavier': 'Xavier University',
    'MSU Mankato': 'Minnesota State University-Mankato',
    'Linfield': 'Linfield University',
    'LSU': 'Louisiana State University',
    'UW-L': 'University of Wisconsin-LaCrosse',
    'Keene St.': 'Keene State College',
    'Penn St': 'Pennsylvania State University',
    'SIUC (W)': 'Southern Illinois University',
    'Virginia Tech': 'Virginia Tech',
    'VASSAR': 'Vassar College',
    'R-MC': 'Randolph-Macon College',
    'Concordia Irvine': 'Concordia University Irvine',
    'Trinity U.': 'Trinity University (Texas)',
    'Miami (Ohio)': 'Miami University (Ohio)',
    'Michigan': 'University of Michigan',
    'E. Connecticut': 'Eastern Connecticut State University',
    "Mt St Mary's": "Mount Saint Mary's University (MD)",
    'GW': 'George Washington University',
    'Neb Wesleyan': 'Nebraska Wesleyan University',
    'Northwestern': 'Northwestern University',
    "Nova S'eastern": 'Nova Southeastern University',
    'SUNY Oneonta': 'Oneonta State University',
    'LIU': 'Long Island University',
    'IUP': 'Indiana University of Pennsylvania',
    'L&C': 'Lewis and Clark College',
    'Adams St.': 'Adams State University',
    'CALU-PA': 'Pennsylvania Western-California',
    'Bridgewater St.': 'Bridgewater State University',
    'Wis.- Green Bay': 'University of Wisconsin-Green Bay',
    'CMU': 'Carnegie Mellon University',
    'Virginia': 'University of Virginia',
    'YCP': 'York College (Pennsylvania)',
    'UTPB': 'University of Texas Permian Basin',
    'UNC Asheville': 'University of North Carolina Asheville',
    'UNLV (W)': 'University of Nevada, Las Vegas (UNLV)',
    'Washington St.': 'Washington State University',
    'Connecticut': 'Connecticut College',
    'Arcadia': 'Arcadia University',
    'UW-Oshkosh': 'University of Wisconsin-Oshkosh',
    'Bryant U (M)': 'Bryant University',
    'W&J': 'Washington & Jefferson College',
    'Northern Ariz': 'Northern Arizona University',
    'WCU': 'Western Colorado University',
    'WestConn': 'Western Connecticut State University',
    'Notre Dame': 'University of Notre Dame',
    'UNC- Pembroke': 'University of North Carolina-Pembroke',
    'UMary': 'University of Mary',
    'Augustana (M)': 'Augustana University',
    'Army': 'U.S. Military Academy (Army)',
    'Duke': 'Duke University',
    "King's": 'Kings College (Pennsylvania)',
    'Washington': 'Washington College (Maryland)',
    'Sou. Virginia': 'Southern Virginia University',
    'Pacific Lutheran': 'Pacific Lutheran University',
    'Augustana (W)': 'Augustana University',
    "St. Michael's": 'Saint Michaels College',
    'Missouri': 'University of Missouri',
    'Grinnell': 'Grinnell College',
    'Cal Lutheran': 'California Lutheran University',
    'California': 'University of California-Berkeley',
    'GA Southern': 'Georgia Southern University',
    'Hawaii': 'University of Hawaii',
    'Missouri S & T': 'Missouri University of Science & Technology',
    'SUNY New Paltz': 'State University of New York at New Paltz',
    'Alabama': 'University of Alabama',
    'Villanova': 'Villanova University',
    'Monmouth': 'Monmouth University',
    'UC Santa Cruz': 'University of California-Santa Cruz',
    'Montevallo': 'University of Montevallo',
    'CSU East Bay': 'California State University East Bay',
    'SUNY Potsdam': 'State University of New York at Potsdam',
    'Carthage': 'Carthage College',
    'Cal Baptist': 'California Baptist University',
    'Grand Canyon': 'Grand Canyon University',
    'Goucher': 'Goucher College',
    'Pomona-Pitzer': 'Pomona-Pitzer Colleges',
    'Piedmont': 'Piedmont University',
    'Grove City': 'Grove City College',
    'Purdue': 'Purdue University',
    'Illinois Chicago (W)': 'University of Illinois at Chicago',
    'WPUNJ': 'William Paterson University of New Jersey',
    'Hendrix': 'Hendrix College',
    'Rose-Hulman': 'Rose-Hulman Institute of Technology',
    'Virginia Wesleya': 'Virginia Wesleyan University',
    'Hartwick': 'Hartwick College',
    'Auburn': 'Auburn University',
    'Carroll': 'Carroll University (WI)',
    'Penn St. Altoona': 'Pennsylvania State University - Altoona',
    'Assumption': 'Assumption University',
    'McDaniel': 'McDaniel College',
    'Massachusetts': 'University of Massachusetts (Amherst)',
    'Air Force (M)': 'U.S. Air Force Academy',
    'Middlebury': 'Middlebury College',
    'Mines': 'Colorado School of Mines',
    'Minnesota': 'University of Minnesota',
    'Missouri St. (M)': 'Missouri State University',
    'Macalester': 'Macalester College',
    'Wingate': 'Wingate University',
    'Wilmington C.': 'Wilmington College (Ohio',
    'Lynchburg': 'University of Lynchburg',
    'Loy. Marymount': 'Loyola Marymount University',
    'Little Rock': 'University of Arkansas-Little Rock',
    'Nebraska Kearney': 'University of Nebraska at Kearney',
    'Nevada': 'University of Nevada',
    'Lees-McRae': 'Lees-McRae College',
    'Northern Colo': 'University of Northern Colorado',
    'Arizona': 'University of Arizona',
    'Lafayette': 'Lafayette College',
    'Westfield State': 'Westfield State University',
    'Georgia': 'University of Georgia',
    'West Virginia': 'West Virginia University',
    'Ohio St': 'Ohio State University',
    'Old Dominion (W)': 'Old Dominion University',
    'Olivet': 'Olivet Nazarene University',
    'Pacific Oregon': 'Pacific University',
    'John Carroll': 'John Carroll University',
    'Gordon': 'Gordon College (MA)',
    'Behrend': 'Penn State Behrend University',
    'Springfield': 'Springfield College',
    'Davis & Elkins': 'Davis and Elkins College',
    'Texas': 'University of Texas',
    'UNLV (M)': 'University of Nevada, Las Vegas (UNLV)',
    'Clarion': 'Clarion University',
    'CSUB': 'California State University, Bakersfield',
    'St. Francis': 'St Francis College Brooklyn (New York)',
    'Clarkson': 'Clarkson University',
    'Cleveland St': 'Cleveland State University',
    "Saint Peter's": 'Saint Peters University',
    'Texas A&M': 'Texas A&M University',
    'Brown': 'Brown University',
    'Salisbury': 'Salisbury University',
    'St. Thomas': 'University of Saint Thomas (MN)',
    'Emory': 'Emory University',
    'FGCU': 'Florida Gulf Coast University',
    'Seattle U (M)': 'Seattle University',
    'St. Olaf': 'St Olaf College',
    'Chicago': 'University of Chicago',
    'Denver': 'University of Denver',
    'St. Bonaventure': 'St Bonaventure University',
    'Utah': 'University of Utah',
    'Southern Cali': 'University of Southern California',
    'Berry': 'Berry College',
    'SUNY Maritime': 'State Maritime University of New York',
    'Gardner-Webb': 'Gardner-Webb University',
    'South Dakota St': 'South Dakota State University',
    'Campbell': 'Campbell University',
    'Valparaiso (W)': 'Valparaiso University',
    'Florida Tech': 'Florida Tech',
    'Centenary (LA)': 'Centenary College',
    'Transylvania': 'Transylvania University',
    'SUNY Oswego': 'State University of New York at Oswego',
    'Fresno Pacific': 'Fresno Pacific University',
    'Franklin': 'Franklin College',
    'South Dakota': 'University of South Dakota',
    "St. Mary's MD": "Saint Mary's College of Maryland",
    'St. Francis Pa.': 'Saint Francis University (Pennsylvania)',
    'Oberlin': 'Oberlin College',
    'Northern State': 'Northern State University',
    'North Texas': 'University of North Texas',
    'New Mexico': 'University of New Mexico',
    'New Hampshire': 'University of New Hampshire',
    "St. Joseph's LI": "Saint Joseph's University (Long Island)",
    "St. Cloud St.-W": 'Saint Cloud State University',
    'Oakland': 'Oakland University',
    'SUNY Fredonia': 'Fredonia State University',
    "St. Kate's": 'St Catherine University',
    'Montclair St.': 'Montclair State University',
    'Tulane': 'Tulane University',
    'Tufts': 'Tufts University',
    'Michigan St': 'Michigan State University',
    'Millikin': 'Millikin University',
    'Mills': 'Mills College',
    'Towson': 'Towson University',
    'Tennessee': 'University of Tennessee',
    'UMBC': 'UMBC',
    'Worcester Poly': 'Worcester Polytechnic Institute',
    'Westminster': 'Westminster College',
    'Sweet Briar': 'Sweet Briar College',
    'Stevens': 'Stevens Institute',
    'Southwestern': 'Southwestern University',
    'Widener': 'Widener University',
    'NJIT': 'New Jersey Institute of Technology',
    'Whitman': 'Whitman College',
    'NMU': 'Northern Michigan University',
    'Wheeling': 'Wheeling University',
    'Staten Island': 'College of Staten Island',
    'Ouachita': 'Ouachita Baptist University',
    'Southwest Minn.': 'Southwest Minnesota State University',
    'Rollins': 'Rollins College',
    'Ramapo': 'Ramapo College of New Jersey',
    'Redlands': 'University of Redlands',
    'Regis': 'Regis College (Massachusetts)',
    'Rensselaer': 'Rensselaer Polytechnic Institute',
    'Rhode Island': 'University of Rhode Island',
    'Rhodes': 'Rhodes College',
    'Rice': 'Rice University',
    'Richmond': 'University of Richmond',
    'Rider': 'Rider University',
    'Ripon': 'Ripon College',
    'Saint Leo': 'Saint Leo University',
    'Occidental': 'Occidental College',
    'Saint Joseph CT': 'University of Saint Joseph',
    'Saginaw Valley': 'Saginaw Valley State University',
    'Rowan': 'Rowan University',
    'Sacred Heart': 'Sacred Heart University',
    'SJCME': 'Saint Josephs College (Maine)',
    'Vermont': 'University of Vermont',
    'Valparaiso (M)': 'Valparaiso University',
    'SUNY Cobleskill': 'State University of New York at Cobleskill',
    'SUNY Cortland': 'State University of New York at Cortland',
    'SUNY Delhi': 'State University of New York at Delhi',
    'Saint Vincent': 'Saint Vincent College',
    'WVWC': 'West Virginia Wesleyan College',
    'Salem (M)': 'Salem University',
    'Salem College': 'Salem College',
    'Oklahoma Baptist': 'Oklahoma Baptist University',
    'Old Dominion (M)': 'Old Dominion University',
    'Wesleyan': 'Wesleyan University',
    'Skidmore': 'Skidmore College',
    'Vanderbilt': 'Vanderbilt University',
    'Ozarks': 'University of the Ozarks',
    'Sioux Falls': 'University of Sioux Falls',
    'Siena': 'Siena College',
    'Penn': 'University of Pennsylvania',
    'Sewanee': 'University of the South (Sewanee)',
    'Seton Hall': 'Seton Hall University',
    'Seattle U (W)': 'Seattle University',
    'Pepperdine': 'Pepperdine University',
    'Pitt-Bradford': 'University of Pittsburgh-Bradford',
    'Merrimack': 'Merrimack College',
    'Principia': 'Principia College',
    'Providence': 'Providence College',
    'Purchase College': 'Purchase College',
    'San Diego St': 'San Diego State University',
    'Queens (NC)': 'Queens University Charlotte',
    'Quincy': 'Quincy University',
    'Miami (FL)': 'University of Miami (Florida)',
    'Messiah': 'Messiah University',
    'Florida': 'University of Florida',
    'Coast Guard': 'U.S. Coast Guard Academy',
    'Biola University': 'Biola University',
    'Greensboro Coll.': 'Greensboro College',
    'Jewell': 'William Jewell College'
}

# %%
col_filtered['School'] = col_filtered['School'].replace(name_mapping)
hs['School'] = hs['School'].replace(name_mapping)
# Out:
# /tmp/ipykernel_1194081/2991944834.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   col_filtered['School'] = col_filtered['School'].replace(name_mapping)
# /tmp/ipykernel_1194081/2991944834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col_filtered['School'] = col_filtered['School'].replace(name_mapping)

# %%
# Group hs by 'Name' and collect the unique 'School's associated with each 'Name'
hs_schools_grouped = hs.groupby('Name')['School'].apply(set).to_dict()

# Group col_filtered by 'Name' and collect the unique 'School's associated with each 'Name'
col_filtered_schools_grouped = col_filtered.groupby('Name')['School'].apply(set).to_dict()

# Create a list to store the results of the comparison
comparison_results = []

# For each 'Name' in col_filtered, check if all associated 'School's are also in hs
for name, schools in col_filtered_schools_grouped.items():
    # Get the schools associated with the current 'Name' in hs
    hs_schools = hs_schools_grouped.get(name, set())
    
    # Check if all schools in col_filtered for this 'Name' are also in hs
    is_subset = schools.issubset(hs_schools)
    
    # Append the result to the comparison_results list
    comparison_results.append((name, is_subset))

# Convert comparison_results to a DataFrame for easy inspection
comparison_df = pd.DataFrame(comparison_results, columns=['Name', 'All_Schools_Match'])

# Display the result
comparison_df.head()
# Out:
#                 Name  All_Schools_Match
# 0          A.J. Zako               True
# 1          AJ Huskey               True
# 2         AJ Mainord               True
# 3            AJ Nybo               True
# 4  ARTHUR KISELNIKOV               True

# %%
col_filtered.Name = col_filtered.Name.astype('string')
hs.Name = hs.Name.astype('string')
# Out:
# /tmp/ipykernel_1194081/629196001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col_filtered.Name = col_filtered.Name.astype('string')

# %%
# 1. Create a list of Names for which all schools match (True) and Names where all schools don't match (False)
names_with_matching_schools = comparison_df[comparison_df['All_Schools_Match'] == True]['Name'].tolist()
names_with_non_matching_schools = comparison_df[comparison_df['All_Schools_Match'] == False]['Name'].tolist()

# 2. Create the hs_reset and mappings
hs_reset = hs.reset_index()
hs_reset.Name = hs_reset.Name.astype('string')

# Create a new column 'Name_School' that combines 'Name' and 'School' for mapping
hs_reset['Name_School'] = hs_reset['Name'] + " - " + hs_reset['School']
name_school_to_id_mapping = hs_reset.set_index('Name_School')['ID'].to_dict()
name_to_id_mapping = hs_reset.set_index('Name')['ID'].to_dict()

# 3. Create a copy of col_filtered to avoid modifying a view
col_filtered_copy = col_filtered.copy()

# Initialize 'Name_School' and 'ID' columns
col_filtered_copy['Name_School'] = col_filtered_copy['Name'] + " - " + col_filtered_copy['School']
col_filtered_copy['ID'] = None  # Initialize the ID column

# 4. Apply mappings using vectorized operations
# Map for Names where all schools match (Name_School mapping)
mask_matching = col_filtered_copy['Name'].isin(names_with_matching_schools)
col_filtered_copy.loc[mask_matching, 'ID'] = col_filtered_copy.loc[mask_matching, 'Name_School'].map(name_school_to_id_mapping)

# Map for Names where not all schools match (Name-only mapping)
mask_non_matching = col_filtered_copy['Name'].isin(names_with_non_matching_schools)
col_filtered_copy.loc[mask_non_matching, 'ID'] = col_filtered_copy.loc[mask_non_matching, 'Name'].map(name_to_id_mapping)

# Ensure the 'ID' column is of the correct type
col_filtered_copy['ID'] = col_filtered_copy['ID'].astype('category')

# Display the result
col_filtered_copy.head(2)
# Out:
#                    Event  Conf_Rank   Time            Name School Standard  \
# 0  50 Freestyle SCY Male          2  20.20   Tiago ASAKAWA   UMBC       NS
# 1  50 Freestyle SCY Male          4  20.72  Niklas Weigelt   UMBC       NS
#
#         Date Gender Division Season  SeasonYear               Time_Adj  \
# 0 2020-02-14      M        I  19_20        2020 0 days 00:00:20.200000
# 1 2020-02-14      M        I  19_20        2020 0 days 00:00:20.720000
#
#    Time_Sec      Points  Div_Rank  NCAA_Rank  Power            Name_School  \
# 0     20.20  664.818090     252.0      291.0  15.96   Tiago ASAKAWA - UMBC
# 1     20.72  616.009888     542.0      690.0   8.38  Niklas Weigelt - UMBC
#
#        ID
# 0  515075
# 1  413265

# %%
col_filtered_copy.shape
# Out:
# (231748, 19)

# %%
col_filtered_copy.ID.nunique()
# Out:
# 11405

# %%
col_filtered_copy[col_filtered_copy.Name=='Brianna Brunk']
# Out:
#                                    Event  Conf_Rank      Time           Name  \
# 254774           50 Freestyle SCY Female        108     28.65  Brianna Brunk
# 254869          100 Freestyle SCY Female         95   1:02.75  Brianna Brunk
# 254937          200 Freestyle SCY Female         63   2:12.38  Brianna Brunk
# 255012          500 Freestyle SCY Female         62   6:36.97  Brianna Brunk
# 255109          50 Backstroke SCY Female         47     34.21  Brianna Brunk
# 255195         200 Backstroke SCY Female         35   2:31.50  Brianna Brunk
# 287042  360.997671     809.0     2247.0   -1.0
# 287086  102.770101    1224.0     2944.0   -1.0
# 287169  252.697054    1443.0     3504.0   -1.0
# 287195  278.682334    1069.0     2708.0   -1.0
# 287233  253.458487    1639.0     4548.0   -1.0
# 287249  333.625452     722.0     2367.0   -1.0
# 287303  285.077464    1725.0     4548.0   -1.0
# 299170  291.547588    3055.0     7365.0   -1.0
# 299199  297.024514    2845.0     7059.0   -1.0
# 299216  331.360647    2266.0     5731.0   -1.0
# 299229  435.910239    1115.0     3364.0   -1.0
# 299246  412.875702     637.0     2040.0   -1.0
# 299255  426.376254     548.0     1627.0   -1.0
# 299332  276.640634     691.0     1544.0   -1.0
# 299346  250.433955    1637.0     4595.0   -1.0
# 299353  314.193618     798.0     2418.0   -1.0
# 299389  397.527283     722.0     2198.0   -1.0
#
#                                               Name_School       ID
# 254774                Brianna Brunk - Millikin University  1309404
# 254869                Brianna Brunk - Millikin University  1309404
# 254937                Brianna Brunk - Millikin University  1309404
# 255012                Brianna Brunk - Millikin University  1309404
# 255109                Brianna Brunk - Millikin University  1309404
# 255195                Brianna Brunk - Millikin University  1309404
# 255210                Brianna Brunk - Millikin University  1309404
# 255259                Brianna Brunk - Millikin University  1309404
# 255302                Brianna Brunk - Millikin University  1309404
# 255449                Brianna Brunk - Millikin University  1309404
# 286852                Brianna Brunk - Millikin University  1309404
# 286923                Brianna Brunk - Millikin University  1309404
# 286972                Brianna Brunk - Millikin University  1309404
# 287013                Brianna Brunk - Millikin University  1309404
# 287042                Brianna Brunk - Millikin University  1309404
# 287086                Brianna Brunk - Millikin University  1309404
# 287169                Brianna Brunk - Millikin University  1309404
# 287195                Brianna Brunk - Millikin University  1309404
# 287233                Brianna Brunk - Millikin University  1309404
# 287249                Brianna Brunk - Millikin University  1309404
# 287303                Brianna Brunk - Millikin University  1309404
# 299170  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299199  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299216  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299229  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299246  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299255  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299332  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299346  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299353  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404
# 299389  Brianna Brunk - Rose-Hulman Institute of Techn...  1309404

# %%
# Create a list to store the results of the comparison, including non-matching schools and all schools in hs
detailed_comparison_results = []

# For each 'Name' in col_filtered, check which 'School's don't match in hs
for name, schools in col_filtered_schools_grouped.items():
    # Get the schools associated with the current 'Name' in hs
    hs_schools = hs_schools_grouped.get(name, set())
    
    # Find the schools in col_filtered that are not in hs
    non_matching_schools = schools - hs_schools
    
    # If there are non-matching schools, add them to the results
    if non_matching_schools:
        detailed_comparison_results.append((name, non_matching_schools, hs_schools))

# Convert detailed_comparison_results to a DataFrame for easy inspection
non_matching_df = pd.DataFrame(detailed_comparison_results, columns=['Name', 'Non_Matching_Schools', 'All_Schools_in_hs'])

# Display the result
non_matching_df.head(20)
# Out:
#                    Name                               Non_Matching_Schools  \
# 0         Aaron Parrott                       {Louisiana State University}
# 1            Abbey Webb                  {North Carolina State University}
# 2           Abby Martin                 {Connecticut College, Bridgewater}
# 3           Abby Miller                {University of Southern California}
# 4   Abdelrahman Elaraby                         {University of Notre Dame}
# 5       Abigail Gibbons                                            {Bates}
# 6        Abigail Greene                              {Westminster College}
# 7        Abigail Nelson                                   {Incarnate Word}
# 8        Abram Hagedorn                                        {McKendree}
# 9            Adam Jones                                    {Carson-Newman}
# 10          Adam Mahler  {Pittsburgh, University of North Carolina, Cha...
# 11        Addi Odonnell                      {Western Colorado University}
# 12        Addison Smith        {University of North Carolina, Chapel Hill}
# 13      Adela Vavrinova                                         {Arkansas}
# 14       Adrian Aguilar          {University of Tampa, Macalester College}
# 15        Adrian Paseta                           {Saint Louis University}
# 16      Adrianna Barone                          {Gardner-Webb University}
# 17          Aeson Akins                             {Augustana University}
# 18   Aidah Shuttleworth                                          {Hanover}
# 19       Aidan Campbell                           {Randolph-Macon College}
#
#                              All_Schools_in_hs
# 0                                 {Louisville}
# 1                          {Auburn University}
# 2                  {University of Connecticut}
# 3    {Hartwick College, University of Vermont}
# 4                                 {Louisville}
# 5                          {Auburn University}
# 6                                   {PennWest}
# 7                {Northern Arizona University}
# 8                  {Notre Dame (Ohio) College}
# 9                {Birmingham Southern College}
# 10                             {East Carolina}
# 11                   {West Chester University}
# 12                                 {Princeton}
# 13                             {East Carolina}
# 14                                {Florida St}
# 15  {California State University, Bakersfield}
# 16                             {Florida Int'l}
# 17                         {Augustana College}
# 18                                   {Bethany}
# 19                   {Rainey McCullers School}

# %%
non_matching_df.shape
# Out:
# (1047, 3)

# %%
col_filtered = col_filtered_copy

# %%
col_filtered[col_filtered.Name=='Nicholas Edwards']
# Out:
#                                  Event  Conf_Rank     Time              Name  \
# 78061            50 Freestyle SCY Male         36    25.97  Nicholas Edwards
# 78070           100 Freestyle SCY Male         32    57.14  Nicholas Edwards
# 78089           50 Backstroke SCY Male         15    29.46  Nicholas Edwards
# 78096          100 Backstroke SCY Male         20  1:07.79  Nicholas Edwards
# 78101          200 Backstroke SCY Male         17  2:31.97  Nicholas Edwards
# 78111        100 Breaststroke SCY Male         23  1:24.47  Nicholas Edwards
# 78119            50 Butterfly SCY Male         24    27.99  Nicholas Edwards
# 78124           100 Butterfly SCY Male         19  1:06.24  Nicholas Edwards
# 78130   100 Individual Medley SCY Male         12  1:03.69  Nicholas Edwards
# 78137   200 Individual Medley SCY Male         17  2:28.14  Nicholas Edwards
# 91286           100 Freestyle SCY Male         24    49.68  Nicholas Edwards
# 91313           200 Freestyle SCY Male          5  1:42.51  Nicholas Edwards
# 91471        100 Breaststroke SCY Male         10  1:01.66  Nicholas Edwards
# 91495        200 Breaststroke SCY Male         14  2:23.19  Nicholas Edwards
# 91512           100 Butterfly SCY Male         12    53.62  Nicholas Edwards
# 91534           200 Butterfly SCY Male          2  1:54.66  Nicholas Edwards
# 91564   200 Individual Medley SCY Male          3  1:54.21  Nicholas Edwards
# 93072           200 Freestyle SCY Male         36  2:05.72  Nicholas Edwards
# 93094           500 Freestyle SCY Male         23  6:08.64  Nicholas Edwards
# 93135           50 Backstroke SCY Male         19    29.31  Nicholas Edwards
# 93160          100 Backstroke SCY Male         25  1:06.20  Nicholas Edwards
# 93178          200 Backstroke SCY Male         17  2:30.12  Nicholas Edwards
# 93237            50 Butterfly SCY Male         17    27.21  Nicholas Edwards
# 120633  600.486637     197.0     1047.0   -1.0
# 120656  553.737280     393.0     1710.0   -1.0
#
#                                               Name_School      ID
# 78061   Nicholas Edwards - Western Connecticut State U...  490867
# 78070   Nicholas Edwards - Western Connecticut State U...  490867
# 78089   Nicholas Edwards - Western Connecticut State U...  490867
# 78096   Nicholas Edwards - Western Connecticut State U...  490867
# 78101   Nicholas Edwards - Western Connecticut State U...  490867
# 78111   Nicholas Edwards - Western Connecticut State U...  490867
# 78119   Nicholas Edwards - Western Connecticut State U...  490867
# 78124   Nicholas Edwards - Western Connecticut State U...  490867
# 78130   Nicholas Edwards - Western Connecticut State U...  490867
# 78137   Nicholas Edwards - Western Connecticut State U...  490867
# 91286   Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 91313   Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 91471   Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 91495   Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 91512   Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 91534   Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 91564   Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 93072   Nicholas Edwards - Western Connecticut State U...  490867
# 93094   Nicholas Edwards - Western Connecticut State U...  490867
# 93135   Nicholas Edwards - Western Connecticut State U...  490867
# 93160   Nicholas Edwards - Western Connecticut State U...  490867
# 93178   Nicholas Edwards - Western Connecticut State U...  490867
# 93237   Nicholas Edwards - Western Connecticut State U...  490867
# 93256   Nicholas Edwards - Western Connecticut State U...  490867
# 93293   Nicholas Edwards - Western Connecticut State U...  490867
# 93311   Nicholas Edwards - Western Connecticut State U...  490867
# 120461  Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 120498  Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 120597  Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 120618  Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 120633  Nicholas Edwards - Rose-Hulman Institute of Te...  663038
# 120656  Nicholas Edwards - Rose-Hulman Institute of Te...  663038

# %%
col_filtered.shape
# Out:
# (231748, 19)

# %%
hs[hs.Name=='Nicholas Edwards']
# Out:
#            ID              Name                                School   Power  \
# 3171   490867  Nicholas Edwards  Western Connecticut State University  100.00
# 11437  663038  Nicholas Edwards   Rose-Hulman Institute of Technology   25.38
#
#       50 Y Free Time 50 S Free Time 50 L Free Time 100 Y Free Time  \
# 3171            <NA>           <NA>           <NA>           55.88
# 11437          22.16           <NA>           <NA>           47.46
#
#       100 S Free Time 100 L Free Time  ... 200 S Fly Points 200 L Fly Points  \
# 3171             <NA>            <NA>  ...              NaN              NaN
# 11437            <NA>            <NA>  ...              NaN              NaN
#
#       100 Y IM Points 100 S IM Points 200 Y IM Points 200 S IM Points  \
# 3171              NaN             NaN             NaN             NaN
# 11437             NaN             NaN           37.73             NaN
#
#       200 L IM Points 400 Y IM Points 400 S IM Points 400 L IM Points
# 3171              NaN             NaN             NaN             NaN
# 11437             NaN           52.17             NaN             NaN
#
# [2 rows x 92 columns]

# %%
mini_df = col_filtered[['ID','Gender']].drop_duplicates()
mini_df.head()
# Out:
#        ID Gender
# 0  515075      M
# 1  413265      M
# 2  394588      M
# 3  471360      M
# 4  395308      M

# %%
mini_df_unique = mini_df.drop_duplicates(subset='ID')

# Now merge the dataframes
hs = hs.merge(mini_df_unique[['ID', 'Gender']], on='ID', how='left')
hs.head()
# Out:
#        ID            Name                              School  Power  \
# 0  515075   Tiago ASAKAWA                                UMBC  15.96
# 1  413265  Niklas Weigelt                                UMBC   8.38
# 2  394588     Ben Beldner                          Binghamton  22.71
# 3  471360     Justin Meyn                          Binghamton  10.06
# 4  395308   Joshua Franco  New Jersey Institute of Technology  12.40
#
#   50 Y Free Time 50 S Free Time 50 L Free Time 100 Y Free Time  \
# 0           <NA>           <NA>          23.31            <NA>
# 1           <NA>           <NA>          23.60           44.36
# 2          21.22           <NA>           <NA>           47.00
# 3          20.87           <NA>           <NA>           45.40
# 4          21.31           <NA>           <NA>           45.65
#
#   100 S Free Time 100 L Free Time  ... 200 L Fly Points 100 Y IM Points  \
# 0           50.21            <NA>  ...              NaN             NaN
# 1            <NA>            <NA>  ...              NaN          100.00
# 2            <NA>            <NA>  ...              NaN             NaN
# 3            <NA>            <NA>  ...              NaN            2.45
# 4            <NA>            <NA>  ...              NaN          100.00
#
#   100 S IM Points 200 Y IM Points 200 S IM Points 200 L IM Points  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN           18.97             NaN             NaN
# 2             NaN           70.80             NaN             NaN
# 3             NaN           21.65             NaN             NaN
# 4             NaN           17.99             NaN             NaN
#
#   400 Y IM Points 400 S IM Points 400 L IM Points Gender
# 0             NaN             NaN             NaN      M
# 1          100.00             NaN             NaN      M
# 2             NaN             NaN             NaN      M
# 3           27.34             NaN             NaN      M
# 4           28.48             NaN             NaN      M
#
# [5 rows x 93 columns]

# %%
hs[hs.Name=='Nicholas Edwards']
# Out:
#            ID              Name                                School   Power  \
# 3171   490867  Nicholas Edwards  Western Connecticut State University  100.00
# 11437  663038  Nicholas Edwards   Rose-Hulman Institute of Technology   25.38
#
#       50 Y Free Time 50 S Free Time 50 L Free Time 100 Y Free Time  \
# 3171            <NA>           <NA>           <NA>           55.88
# 11437          22.16           <NA>           <NA>           47.46
#
#       100 S Free Time 100 L Free Time  ... 200 L Fly Points 100 Y IM Points  \
# 3171             <NA>            <NA>  ...              NaN             NaN
# 11437            <NA>            <NA>  ...              NaN             NaN
#
#       100 S IM Points 200 Y IM Points 200 S IM Points 200 L IM Points  \
# 3171              NaN             NaN             NaN             NaN
# 11437             NaN           37.73             NaN             NaN
#
#       400 Y IM Points 400 S IM Points 400 L IM Points Gender
# 3171              NaN             NaN             NaN      M
# 11437           52.17             NaN             NaN      M
#
# [2 rows x 93 columns]

# %%
hs.dtypes
# Out:
# ID                         object
# Name               string[python]
# School                   category
# Power                     float64
# 50 Y Free Time     string[python]
#                         ...
# 200 L IM Points           float64
# 400 Y IM Points           float64
# 400 S IM Points           float64
# 400 L IM Points           float64
# Gender                   category
# Length: 93, dtype: object

# %%
hs.ID = hs.ID.astype('int64')

# %%
col_filtered.dtypes
col_filtered.ID = col_filtered.ID.astype('int64')
col_filtered.dtypes
# Out:
# Event                 category
# Conf_Rank                int64
# Time            string[python]
# Name            string[python]
# School                category
# Standard              category
# Date            datetime64[ns]
# Gender                category
# Division              category
# Season                category
# SeasonYear               int64
# Time_Adj       timedelta64[ns]
# Time_Sec               float64
# Points                 float64
# Div_Rank               float64
# NCAA_Rank              float64
# Power                  float64
# Name_School     string[python]
# ID                       int64
# dtype: object

# %%
hs.to_parquet('corrected_HS_1_20.parquet',index=True)
col_filtered.to_parquet('corrected_Col_1_20.parquet',index=True)
